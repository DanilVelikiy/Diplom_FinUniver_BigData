# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
#import plotly.express as px

# %%
file = 'df2clusteringV3.csv'
df = pd.read_csv(file, index_col=0)
df
# Out:
#       Manufacturer   CategoryInSegmentInCompete  cluster
# Units
# 12          Natura   UrbanConvenienceNotCompete        3
# 7            Pirum  RuralProductivityNotCompete        5
# 3        VanArsdel     UrbanModerationIsCompete        6
# 3           Currus        RuralSelectNotCompete        6
# 3            Abbas     UrbanModerationIsCompete        6
# ...            ...                          ...      ...
# 1           Natura   UrbanConvenienceNotCompete        0
# 1           Natura   UrbanConvenienceNotCompete        0
# 1         Victoria       UrbanExtremeNotCompete        0
# 1            Pirum        UrbanRegularIsCompete        0
# 1            Pirum        UrbanRegularIsCompete        0
#
# [877920 rows x 3 columns]

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877920 entries, 0 to 877919
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Units                       877920 non-null  int64
#  1   Manufacturer                877920 non-null  object
#  2   CategoryInSegmentInCompete  877920 non-null  object
#  3   cluster                     877920 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 26.8+ MB

# %%
feature_cat = ['Manufacturer', 'CategoryInSegmentInCompete', 'cluster']

df[feature_cat] = df[feature_cat].apply ( lambda x: pd.factorize (x)[ 0 ])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877920 entries, 0 to 877919
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Units                       877920 non-null  int64
#  1   Manufacturer                877920 non-null  int64
#  2   CategoryInSegmentInCompete  877920 non-null  int64
#  3   cluster                     877920 non-null  int64
# dtypes: int64(4)
# memory usage: 26.8 MB

# %%
sns.set(font_scale=0.7)
plt.figure(figsize=(12,4))
sns.heatmap(
    df.corr(),
    cmap='RdBu_r', # задаёт цветовую схему
    annot=True, # рисует значения внутри ячеек
    vmin=-1, vmax=1); # указывает начало цветовых кодов от -1 до 1.

# %%
sns.pairplot(df, hue='cluster')
# Out:
# /venv_autoeda/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
