# %% [markdown]
# # Прогнозирование №8.7 - ПРОГНОЗ ПРИБЫЛИ ДЛЯ НОВЫХ ПРОДУКТОВ НА МОДЕЛИ КЛАССИФИКАЦИИ ДЛЯ ПРИБЫЛИ ДО 6000

# %%
import pandas as pd

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         29 mins 10 secs
# H2O_cluster_timezone:       Etc/GMT
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.42.0.2
# H2O_cluster_version_age:    2 months and 14 days
# H2O_cluster_name:           H2O_from_python_unknownUser_fsg0v9
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.468 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.8.10 final
# --------------------------  ----------------------------------

# %%
df_new_product_templates = pd.DataFrame(
    {
        'Manufacturer' : ['Abbas', 'Barba', 'Pirum', 'Natura', 'VanArsdel', 'Salvus', 'Victoria'],
        'MonthNo' : [1, 1, 1, 1, 1, 1, 1],
        'Model_id_number' : ['33', '33', '33', '33', '33', '33', '33'],
        'CategoryInSegmentInCompete' : ['RuralProductivityNotCompete', 'RuralProductivityNotCompete', 'RuralProductivityNotCompete', 'RuralProductivityNotCompete', 'RuralProductivityNotCompete', 'RuralProductivityNotCompete', 'RuralProductivityNotCompete']
    }
)
df_new_product = df_new_product_templates.copy()
for k in range(2,13):
    df_df = df_new_product_templates.copy()
    df_df['MonthNo'] = k
    df_new_product = pd.concat([df_new_product, df_df], ignore_index=True)
#    print(df_new_product)
    
df_new_product
# Out:
#    Manufacturer  MonthNo Model_id_number   CategoryInSegmentInCompete
# 0         Abbas        1              33  RuralProductivityNotCompete
# 1         Barba        1              33  RuralProductivityNotCompete
# 2         Pirum        1              33  RuralProductivityNotCompete
# 3        Natura        1              33  RuralProductivityNotCompete
# 4     VanArsdel        1              33  RuralProductivityNotCompete
# ..          ...      ...             ...                          ...
# 79        Pirum       12              33  RuralProductivityNotCompete
# 80       Natura       12              33  RuralProductivityNotCompete
# 81    VanArsdel       12              33  RuralProductivityNotCompete
# 82       Salvus       12              33  RuralProductivityNotCompete
# 83     Victoria       12              33  RuralProductivityNotCompete
#
# [84 rows x 4 columns]

# %%
df_new_product.to_csv('df_new_product.csv')

# %%
df = h2o.H2OFrame(df_new_product)
df
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Manufacturer      MonthNo    Model_id_number  CategoryInSegmentInCompete
# --------------  ---------  -----------------  ----------------------------
# Abbas                   1                 33  RuralProductivityNotCompete
# Barba                   1                 33  RuralProductivityNotCompete
# Pirum                   1                 33  RuralProductivityNotCompete
# Natura                  1                 33  RuralProductivityNotCompete
# VanArsdel               1                 33  RuralProductivityNotCompete
# Salvus                  1                 33  RuralProductivityNotCompete
# Victoria                1                 33  RuralProductivityNotCompete
# Abbas                   2                 33  RuralProductivityNotCompete
# Barba                   2                 33  RuralProductivityNotCompete
# ...

# %% [markdown]
# # Загрузка модели и прогнозирование

# %%
# %pwd
# Out:
# '/home/jupyter/Diplom'

# %%
import sys, os, os.path
clsf_model = h2o.load_model("/home/jupyter/Diplom/models/GBM_model_python_1696926786466_1")

# %%
clsf_model
# Out:
# Model Details
# ...
# H2OGradientBoostingEstimator : Gradient Boosting Machine
# Model Key: GBM_model_python_1696926786466_1
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     50                 500                         225594                 5            5            5             23            32            31.244
#
# ModelMetricsMultinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.24924099893962653
# RMSE: 0.4992404219808594
# LogLoss: 0.7469169867490432
# Mean Per-Class Error: 0.24381178632743294
# AUC table was not computed: it is either disabled (model parameter 'auc_type' was set to AUTO or NONE) or the domain size exceeds the limit (maximum is 50 domains).
# ...

# %%
predict_classification_revenue_new_product = clsf_model.predict(df)
predict_classification_revenue_new_product
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# /usr/local/lib/python3.8/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Manufacturer' has levels not trained on: ["Barba"]
#   warnings.warn(w)
# predict            Revenue_cat #1    Revenue_cat #10    Revenue_cat #2    Revenue_cat #3    Revenue_cat #4    Revenue_cat #5    Revenue_cat #6    Revenue_cat #7    Revenue_cat #8    Revenue_cat #9
# ---------------  ----------------  -----------------  ----------------  ----------------  ----------------  ----------------  ----------------  ----------------  ----------------  ----------------
# Revenue_cat #10         0.013289          0.763158           0.0085564        0.00895341         0.0252439         0.0495984         0.049807         0.00862433         0.0225869         0.0501827
# ...

# %%
h2o.download_csv(predict_classification_revenue_new_product, "df2predict_classification_revenue_new_product.csv")
# Out:
# '/home/jupyter/Diplom/df2predict_classification_revenue_new_product.csv'
