# %%
import pandas as pd

# %%
file = 'df4eda.csv'
df = pd.read_csv(file, index_col=0)

# удалю Product ID, для кластеризации не нужен

# c годом так же распрощаюсь, интересует величина, которая будет предсказумеа и повторятся из года в год туда же
# и все связанное с датой

#MfgisVanArsdel и isVanArsdel - уберу, слишком узкие и специфчные кажется

#City и State тоже уберу
df = df.drop(['ProductID', 'Year','Date', 'MonthIndex', 'Rolling Period Sort', 'Rolling Period',
             'Running Months', 'Month', 'Quarter', 'MfgisVanArsdel', 'isVanArsdel',
             'City', 'State'], axis=1)

# Units надо объединить, пусть будет один и больше одного
units_cat = {1:"one", 2:"moreone", 3:"moreone", 4:"moreone", 5:"moreone", 6:"moreone",
            7:"moreone", 8:"moreone", 9:"moreone", 10:"moreone", 11:"moreone", 12:"moreone"}
df['Units'] = df['Units'].map(units_cat)

#df['Units'].unique()
df
# Out:
# /tmp/ipykernel_23204/338098448.py:2: DtypeWarning: Columns (22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, index_col=0)
#            Zip    Units  Revenue_T Manufacturer Category       Segment  \
# 0         6111  moreone   31676.40       Natura    Urban   Convenience
# 1        92879  moreone   11020.59        Pirum    Rural  Productivity
# 2        92879  moreone   11020.59        Pirum    Rural  Productivity
# 3        32901  moreone   35010.36    VanArsdel    Urban    Moderation
# 4        84770  moreone   16441.11       Currus    Rural        Select
# ...        ...      ...        ...          ...      ...           ...
# 1048570  11752      one    5291.37       Natura    Urban   Convenience
# 1048571  39367      one    5291.37       Natura    Urban   Convenience
# 1048572  98311      one    6614.37     Victoria    Urban       Extreme
# 1048573  95018      one    4976.37        Pirum    Urban       Regular
# 1048574  98682      one    4976.37        Pirum    Urban       Regular
#
#                 Product IsCompeteHide  ManufacturerID_x IsCompete  MonthNo  \
# 0          Natura UC-44             N                 8        No       12
# 1           Pirum RP-32             N                10        No       12
# 2           Pirum RP-31             N                10        No       12
# 3         Maximus UM-94             Y                 7       Yes       12
# 4          Currus RS-08             N                 4        No       12
# ...                 ...           ...               ...       ...      ...
# 1048570    Natura UC-53             N                 8        No        4
# 1048571    Natura UC-53             N                 8        No        4
# 1048572  Victoria UE-22             N                14        No        4
# 1048573     Pirum UR-01             Y                10       Yes        4
# 1048574     Pirum UR-01             Y                10       Yes        4
#
#         MonthName  MonthID  RunningMonths  Running Year   Region  \
# 0             Dec   201412              1           1.0     East
# 1             Dec   201412              1           1.0     West
# 2             Dec   201412              1           1.0     West
# 3             Dec   201412              1           1.0     East
# 4             Dec   201412              1           1.0     West
# ...           ...      ...            ...           ...      ...
# 1048570       Apr   200204            153          13.0     East
# 1048571       Apr   200204            153          13.0  Central
# 1048572       Apr   200204            153          13.0     West
# 1048573       Apr   200204            153          13.0     West
# 1048574       Apr   200204            153          13.0     West
#
#              District  ManufacturerID_y
# 0        District #02                 8
# 1        District #38                10
# 2        District #38                10
# 3        District #10                 7
# 4        District #38                 4
# ...               ...               ...
# 1048570  District #03                 8
# 1048571  District #24                 8
# 1048572  District #34                14
# 1048573  District #36                10
# 1048574  District #34                10
#
# [1048575 rows x 18 columns]
